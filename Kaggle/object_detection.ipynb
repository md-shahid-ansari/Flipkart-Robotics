# %%
pip install supervision ultralytics

# %%
# !apt install tesseract-ocr
# !pip install pytesseract

# %%
import re
import time
import cv2
from ultralytics import YOLO
import supervision as sv
import pytesseract
from google.colab.patches import cv2_imshow

# %%
# Load the YOLOv8 model
model = YOLO("yolov8s.pt")

# Box annotator
bbox_annotator = sv.BoxAnnotator()

# %%
# Load the video
video = cv2.VideoCapture("/content/drive/MyDrive/Robo/video/video.mp4")

frame_count = 0  # To count frames
predefined_product_details = {
    "Lays": {"variety": "Classic Salted", "company": "PepsiCo"},
    "Lays Masala": {"variety": "India's Magic Masala", "company": "PepsiCo"},
    "Lays Tomato": {"variety": "Tomato Tango", "company": "PepsiCo"},
    "Kurkure": {"variety": "Masala Munch", "company": "PepsiCo"},
    "Kurkure Green": {"variety": "Green Chutney Rajasthani Style", "company": "PepsiCo"},
    # Add more predefined products here
}

side = "front"  # Track which side is being processed
side_duration = 0.2  # Time duration per side in seconds

ocr_results = {}  # Dictionary to store front and back OCR results


def extract_expiry_date(text):
    """
    Extract expiry date from OCR text by searching for keywords like 'EXP', 'Expiry', 'Best Before', etc.
    """
    # Define regular expressions for matching dates (e.g., DD/MM/YYYY, MM/YYYY, etc.)
    date_patterns = [
        r"\b\d{1,2}[/-]\d{1,2}[/-]\d{2,4}\b",  # DD/MM/YYYY or similar
        r"\b\d{1,2}[/-]\d{2,4}\b",  # MM/YYYY or similar
    ]

    # Define keywords to search for
    keywords = ["EXP", "Expiry", "Best Before", "Use By", "BBE"]

    # Check if any of the keywords are in the text
    for keyword in keywords:
        if keyword.lower() in text.lower():
            # Try to find the date following the keyword
            for pattern in date_patterns:
                match = re.search(pattern, text)
                if match:
                    return match.group()  # Return the first matched date

    return "No expiry date found"  # Return this if no expiry date is detected


while video.isOpened():
    ret, frame = video.read()
    if ret:
        # Run YOLOv8 inference on the frame
        result = model(frame)[0]

        # Extract detections
        detections = sv.Detections.from_ultralytics(result)

        # Filter detections by confidence
        detections = detections[detections.confidence > 0.5]

        # Annotate the frame with bounding boxes and labels
        frame = bbox_annotator.annotate(scene=frame, detections=detections)

        # Display the frame with bounding boxes using cv2_imshow
        # cv2_imshow(frame)

        # For each detection, crop the detected object and store OCR text
        for i, (box, class_id) in enumerate(zip(detections.xyxy, detections.class_id)):
            # Crop the object based on detection bounding box
            x_min, y_min, x_max, y_max = map(int, box)
            cropped_object = frame[y_min:y_max, x_min:x_max]

            # Apply OCR and store results depending on side
            if side == "front":
                ocr_text = pytesseract.image_to_string(cropped_object)
                ocr_results[i] = {"front_text": ocr_text, "class_id": class_id}  # Store front side OCR and class_id

            elif side == "back":
                ocr_text = pytesseract.image_to_string(cropped_object)
                if i in ocr_results:
                    ocr_results[i]["back_text"] = ocr_text  # Store back side OCR

        # Switch sides after 0.2 seconds for front and back alternation
        time.sleep(side_duration)
        if side == "front":
            side = "back"
        else:
            # Process and print the details after both sides are captured
            for i, result in ocr_results.items():
                front_text = result.get("front_text", "")
                back_text = result.get("back_text", "")
                class_id = result.get("class_id", "")

                # If the detected object is a known packet, print details and expiry
                detected_product = None
                for product_name, details in predefined_product_details.items():
                    if product_name.lower() in front_text.lower():
                        detected_product = product_name
                        expiry_date = extract_expiry_date(back_text)  # Extract expiry date from back side
                        print(f"Detected {product_name}:")
                        print(f"  - Variety: {details['variety']}")
                        print(f"  - Company: {details['company']}")
                        print(f"  - Expiry Date: {expiry_date}")
                        break

                # If it's not a packet, assume it's a fruit/vegetable and print the name from class_id
                if not detected_product:
                    fruit_or_veg_name = model.names[class_id]  # Get the name of the detected fruit/vegetable
                    print(f"Detected a fruit/vegetable: {fruit_or_veg_name}")
                    # Freshness check will be implemented later

            # Clear the OCR results after processing both sides
            ocr_results.clear()
            side = "front"  # Reset to front for next object

        # Increment frame count
        frame_count += 1

    else:
        break

# Release the video capture
video.release()
# Out:
# 0: 384x640 2 oranges, 468.8ms
# Speed: 4.6ms preprocess, 468.8ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 oranges, 535.7ms
# Speed: 2.7ms preprocess, 535.7ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
# Detected a fruit/vegetable: orange
#
# 0: 384x640 2 oranges, 528.8ms
# Speed: 7.7ms preprocess, 528.8ms inference, 4.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 oranges, 557.6ms
# Speed: 2.7ms preprocess, 557.6ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 oranges, 422.4ms
# Speed: 2.8ms preprocess, 422.4ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 orange, 345.7ms
# Speed: 3.7ms preprocess, 345.7ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 339.0ms
# Speed: 2.7ms preprocess, 339.0ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 343.8ms
# Speed: 2.6ms preprocess, 343.8ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 341.3ms
# Speed: 2.7ms preprocess, 341.3ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 orange, 347.4ms
# Speed: 5.1ms preprocess, 347.4ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 orange, 352.3ms
# Speed: 2.7ms preprocess, 352.3ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 orange, 338.1ms
# Speed: 2.8ms preprocess, 338.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 orange, 365.8ms
# Speed: 3.3ms preprocess, 365.8ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 orange, 345.7ms
# Speed: 2.8ms preprocess, 345.7ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 orange, 349.9ms
# Speed: 2.7ms preprocess, 349.9ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 bird, 345.6ms
# Speed: 3.3ms preprocess, 345.6ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 carrot, 352.6ms
# Speed: 4.8ms preprocess, 352.6ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 carrot, 353.5ms
# Speed: 2.7ms preprocess, 353.5ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 carrot, 341.6ms
# Speed: 4.8ms preprocess, 341.6ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 370.5ms
# Speed: 4.1ms preprocess, 370.5ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 carrot, 358.1ms
# Speed: 5.9ms preprocess, 358.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 carrot, 368.0ms
# Speed: 2.8ms preprocess, 368.0ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 carrot, 563.1ms
# Speed: 3.6ms preprocess, 563.1ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 550.3ms
# Speed: 3.4ms preprocess, 550.3ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 563.0ms
# Speed: 2.8ms preprocess, 563.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 586.0ms
# Speed: 2.8ms preprocess, 586.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 429.1ms
# Speed: 2.9ms preprocess, 429.1ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 orange, 348.5ms
# Speed: 4.2ms preprocess, 348.5ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 orange, 369.4ms
# Speed: 2.7ms preprocess, 369.4ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 orange, 362.4ms
# Speed: 2.7ms preprocess, 362.4ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 orange, 349.7ms
# Speed: 2.8ms preprocess, 349.7ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 orange, 348.8ms
# Speed: 4.7ms preprocess, 348.8ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 orange, 353.3ms
# Speed: 2.7ms preprocess, 353.3ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 385.3ms
# Speed: 2.9ms preprocess, 385.3ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 352.0ms
# Speed: 4.5ms preprocess, 352.0ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 orange, 365.4ms
# Speed: 2.7ms preprocess, 365.4ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 orange, 352.8ms
# Speed: 4.6ms preprocess, 352.8ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 orange, 351.1ms
# Speed: 5.0ms preprocess, 351.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 orange, 356.7ms
# Speed: 5.8ms preprocess, 356.7ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 orange, 353.8ms
# Speed: 3.2ms preprocess, 353.8ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 orange, 352.2ms
# Speed: 3.0ms preprocess, 352.2ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 orange, 351.1ms
# Speed: 2.7ms preprocess, 351.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 orange, 355.7ms
# Speed: 2.7ms preprocess, 355.7ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 434.1ms
# Speed: 2.8ms preprocess, 434.1ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 orange, 564.0ms
# Speed: 5.1ms preprocess, 564.0ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 orange, 548.1ms
# Speed: 2.8ms preprocess, 548.1ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
# Detected a fruit/vegetable: orange
#
# 0: 384x640 2 oranges, 570.3ms
# Speed: 2.7ms preprocess, 570.3ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 orange, 482.8ms
# Speed: 2.7ms preprocess, 482.8ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Detected a fruit/vegetable: orange
#
# 0: 384x640 1 orange, 355.1ms
# Speed: 2.9ms preprocess, 355.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 orange, 363.8ms
# Speed: 3.1ms preprocess, 363.8ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 orange, 359.5ms
# Speed: 2.9ms preprocess, 359.5ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 orange, 349.2ms
# Speed: 3.3ms preprocess, 349.2ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
# Detected a fruit/vegetable: orange
#
# 0: 384x640 1 orange, 350.3ms
# Speed: 2.4ms preprocess, 350.3ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 orange, 336.2ms
# Speed: 3.3ms preprocess, 336.2ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
# Detected a fruit/vegetable: orange
#
# 0: 384x640 2 oranges, 349.3ms
# Speed: 2.9ms preprocess, 349.3ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 oranges, 341.1ms
# Speed: 2.3ms preprocess, 341.1ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
# Detected a fruit/vegetable: orange
#
# 0: 384x640 2 oranges, 334.3ms
# Speed: 2.2ms preprocess, 334.3ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 oranges, 340.6ms
# Speed: 2.7ms preprocess, 340.6ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
# Detected a fruit/vegetable: orange
#
# 0: 384x640 2 oranges, 351.6ms
# Speed: 3.4ms preprocess, 351.6ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 oranges, 337.4ms
# Speed: 3.3ms preprocess, 337.4ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
# Detected a fruit/vegetable: orange
#
# 0: 384x640 2 oranges, 340.6ms
# Speed: 2.7ms preprocess, 340.6ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 oranges, 348.8ms
# Speed: 2.2ms preprocess, 348.8ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
# Detected a fruit/vegetable: orange
#
# 0: 384x640 1 orange, 484.5ms
# Speed: 2.8ms preprocess, 484.5ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 orange, 523.3ms
# Speed: 8.3ms preprocess, 523.3ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
# Detected a fruit/vegetable: orange
#
# 0: 384x640 1 orange, 541.2ms
# Speed: 5.2ms preprocess, 541.2ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 orange, 561.9ms
# Speed: 2.9ms preprocess, 561.9ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 orange, 387.9ms
# Speed: 3.7ms preprocess, 387.9ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 orange, 366.6ms
# Speed: 2.8ms preprocess, 366.6ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
# Detected a fruit/vegetable: orange
#
# 0: 384x640 1 orange, 350.8ms
# Speed: 3.2ms preprocess, 350.8ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 orange, 1 carrot, 349.8ms
# Speed: 3.4ms preprocess, 349.8ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 orange, 355.6ms
# Speed: 2.7ms preprocess, 355.6ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 orange, 1 carrot, 343.9ms
# Speed: 2.7ms preprocess, 343.9ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 carrot, 345.5ms
# Speed: 2.9ms preprocess, 345.5ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 orange, 1 carrot, 347.3ms
# Speed: 2.7ms preprocess, 347.3ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 carrot, 374.2ms
# Speed: 2.6ms preprocess, 374.2ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 351.6ms
# Speed: 2.7ms preprocess, 351.6ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 368.1ms
# Speed: 3.7ms preprocess, 368.1ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 348.9ms
# Speed: 2.7ms preprocess, 348.9ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 381.5ms
# Speed: 2.7ms preprocess, 381.5ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 360.0ms
# Speed: 3.6ms preprocess, 360.0ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 344.1ms
# Speed: 2.8ms preprocess, 344.1ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 363.8ms
# Speed: 2.9ms preprocess, 363.8ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 354.3ms
# Speed: 2.8ms preprocess, 354.3ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 457.9ms
# Speed: 2.7ms preprocess, 457.9ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 orange, 550.5ms
# Speed: 2.6ms preprocess, 550.5ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 orange, 561.4ms
# Speed: 2.9ms preprocess, 561.4ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 orange, 563.7ms
# Speed: 2.8ms preprocess, 563.7ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 orange, 605.4ms
# Speed: 2.7ms preprocess, 605.4ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
# Detected a fruit/vegetable: orange
#
# 0: 384x640 1 orange, 347.1ms
# Speed: 4.9ms preprocess, 347.1ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 orange, 334.3ms
# Speed: 2.4ms preprocess, 334.3ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
# Detected a fruit/vegetable: orange
#
# 0: 384x640 1 orange, 348.8ms
# Speed: 5.1ms preprocess, 348.8ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 orange, 352.0ms
# Speed: 4.4ms preprocess, 352.0ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
# Detected a fruit/vegetable: orange
#
# 0: 384x640 1 orange, 352.3ms
# Speed: 2.8ms preprocess, 352.3ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 orange, 346.3ms
# Speed: 4.9ms preprocess, 346.3ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Detected a fruit/vegetable: orange
#
# 0: 384x640 1 orange, 354.0ms
# Speed: 3.7ms preprocess, 354.0ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 orange, 346.2ms
# Speed: 3.2ms preprocess, 346.2ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 orange, 348.7ms
# Speed: 2.8ms preprocess, 348.7ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 orange, 344.3ms
# Speed: 5.3ms preprocess, 344.3ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 orange, 364.0ms
# Speed: 5.6ms preprocess, 364.0ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 orange, 357.7ms
# Speed: 2.8ms preprocess, 357.7ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
# Detected a fruit/vegetable: orange
#
# 0: 384x640 1 orange, 356.2ms
# Speed: 2.7ms preprocess, 356.2ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 orange, 356.0ms
# Speed: 3.3ms preprocess, 356.0ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
# Detected a fruit/vegetable: orange
#
# 0: 384x640 1 orange, 348.2ms
# Speed: 3.2ms preprocess, 348.2ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 orange, 535.0ms
# Speed: 3.3ms preprocess, 535.0ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
# Detected a fruit/vegetable: orange
#
# 0: 384x640 1 orange, 537.7ms
# Speed: 2.8ms preprocess, 537.7ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 orange, 561.6ms
# Speed: 4.2ms preprocess, 561.6ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 orange, 591.9ms
# Speed: 3.7ms preprocess, 591.9ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 orange, 427.6ms
# Speed: 7.1ms preprocess, 427.6ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Detected a fruit/vegetable: orange
#
# 0: 384x640 1 orange, 351.3ms
# Speed: 4.1ms preprocess, 351.3ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 orange, 339.6ms
# Speed: 2.8ms preprocess, 339.6ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
# Detected a fruit/vegetable: orange
#
# 0: 384x640 1 orange, 343.3ms
# Speed: 5.0ms preprocess, 343.3ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 orange, 353.8ms
# Speed: 4.7ms preprocess, 353.8ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 345.6ms
# Speed: 4.5ms preprocess, 345.6ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 orange, 370.2ms
# Speed: 3.5ms preprocess, 370.2ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 orange, 346.5ms
# Speed: 5.2ms preprocess, 346.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 orange, 371.0ms
# Speed: 3.5ms preprocess, 371.0ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 orange, 356.8ms
# Speed: 2.9ms preprocess, 356.8ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 orange, 337.6ms
# Speed: 2.7ms preprocess, 337.6ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
# Detected a fruit/vegetable: orange
#
# 0: 384x640 1 orange, 369.6ms
# Speed: 2.8ms preprocess, 369.6ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 orange, 342.0ms
# Speed: 3.7ms preprocess, 342.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Detected a fruit/vegetable: orange
#
# 0: 384x640 1 orange, 360.4ms
# Speed: 2.8ms preprocess, 360.4ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 orange, 352.4ms
# Speed: 2.9ms preprocess, 352.4ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
# Detected a fruit/vegetable: orange
#
# 0: 384x640 1 orange, 367.9ms
# Speed: 2.3ms preprocess, 367.9ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 orange, 567.7ms
# Speed: 2.7ms preprocess, 567.7ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 orange, 561.2ms
# Speed: 2.8ms preprocess, 561.2ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 orange, 573.4ms
# Speed: 3.5ms preprocess, 573.4ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 orange, 546.5ms
# Speed: 5.8ms preprocess, 546.5ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 orange, 465.8ms
# Speed: 3.9ms preprocess, 465.8ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 orange, 347.4ms
# Speed: 4.9ms preprocess, 347.4ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 orange, 354.4ms
# Speed: 4.3ms preprocess, 354.4ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 orange, 344.1ms
# Speed: 3.9ms preprocess, 344.1ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 orange, 344.5ms
# Speed: 2.7ms preprocess, 344.5ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 orange, 355.7ms
# Speed: 2.8ms preprocess, 355.7ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 orange, 360.4ms
# Speed: 3.2ms preprocess, 360.4ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 orange, 357.0ms
# Speed: 4.2ms preprocess, 357.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 orange, 362.6ms
# Speed: 2.7ms preprocess, 362.6ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 352.8ms
# Speed: 2.8ms preprocess, 352.8ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 363.0ms
# Speed: 2.8ms preprocess, 363.0ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 orange, 359.8ms
# Speed: 2.8ms preprocess, 359.8ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 orange, 355.7ms
# Speed: 3.2ms preprocess, 355.7ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 356.9ms
# Speed: 3.3ms preprocess, 356.9ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 orange, 354.0ms
# Speed: 5.2ms preprocess, 354.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 orange, 362.8ms
# Speed: 2.8ms preprocess, 362.8ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 orange, 350.3ms
# Speed: 5.3ms preprocess, 350.3ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 540.7ms
# Speed: 2.8ms preprocess, 540.7ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 556.2ms
# Speed: 2.6ms preprocess, 556.2ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 554.2ms
# Speed: 2.7ms preprocess, 554.2ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 orange, 569.2ms
# Speed: 2.7ms preprocess, 569.2ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 orange, 582.1ms
# Speed: 2.7ms preprocess, 582.1ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 369.3ms
# Speed: 2.8ms preprocess, 369.3ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 orange, 353.1ms
# Speed: 2.9ms preprocess, 353.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 orange, 371.9ms
# Speed: 4.5ms preprocess, 371.9ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 orange, 346.2ms
# Speed: 5.2ms preprocess, 346.2ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 orange, 364.4ms
# Speed: 4.5ms preprocess, 364.4ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 orange, 357.4ms
# Speed: 4.3ms preprocess, 357.4ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 orange, 348.1ms
# Speed: 2.8ms preprocess, 348.1ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 orange, 367.9ms
# Speed: 3.4ms preprocess, 367.9ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 orange, 344.9ms
# Speed: 2.8ms preprocess, 344.9ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 orange, 364.9ms
# Speed: 5.7ms preprocess, 364.9ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 orange, 346.7ms
# Speed: 3.3ms preprocess, 346.7ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 orange, 368.9ms
# Speed: 5.1ms preprocess, 368.9ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 orange, 359.6ms
# Speed: 3.9ms preprocess, 359.6ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
# Detected a fruit/vegetable: orange
#
# 0: 384x640 1 orange, 342.3ms
# Speed: 4.3ms preprocess, 342.3ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 orange, 355.1ms
# Speed: 2.8ms preprocess, 355.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Detected a fruit/vegetable: orange
#
# 0: 384x640 1 orange, 343.3ms
# Speed: 3.8ms preprocess, 343.3ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 orange, 389.9ms
# Speed: 3.9ms preprocess, 389.9ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 orange, 565.4ms
# Speed: 5.5ms preprocess, 565.4ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 orange, 571.6ms
# Speed: 5.2ms preprocess, 571.6ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 orange, 564.2ms
# Speed: 2.7ms preprocess, 564.2ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 orange, 598.3ms
# Speed: 3.6ms preprocess, 598.3ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 orange, 420.1ms
# Speed: 3.9ms preprocess, 420.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 orange, 358.1ms
# Speed: 2.8ms preprocess, 358.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 orange, 342.7ms
# Speed: 2.8ms preprocess, 342.7ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 orange, 355.2ms
# Speed: 3.1ms preprocess, 355.2ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 orange, 350.5ms
# Speed: 2.7ms preprocess, 350.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 orange, 332.0ms
# Speed: 2.8ms preprocess, 332.0ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
# Detected a fruit/vegetable: orange
#
# 0: 384x640 1 orange, 351.2ms
# Speed: 2.7ms preprocess, 351.2ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 orange, 352.1ms
# Speed: 4.4ms preprocess, 352.1ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
# Detected a fruit/vegetable: orange
#
# 0: 384x640 1 orange, 347.4ms
# Speed: 3.1ms preprocess, 347.4ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 orange, 350.7ms
# Speed: 2.7ms preprocess, 350.7ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
# Detected a fruit/vegetable: orange
#
# 0: 384x640 1 orange, 356.9ms
# Speed: 2.7ms preprocess, 356.9ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 orange, 360.9ms
# Speed: 3.7ms preprocess, 360.9ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 orange, 376.7ms
# Speed: 3.4ms preprocess, 376.7ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 orange, 354.3ms
# Speed: 3.5ms preprocess, 354.3ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
# Detected a fruit/vegetable: orange
